# %%
import pandas as pd 
import numpy as np 

metadata = pd.read_csv("full_metadata.csv", sep=",")
metadata
# Out:
#        SampleID       Label    Run  \
# 0     ZKI68A1HD     Healthy  R7926
# 1     ZKI75A1HD     Healthy  R7926
# 2     ZKJ26A1HD     Healthy  R7926
# 3     ZKJ49A1HD     Healthy  R7926
# 4     ZKJ66A1HD     Healthy  R7926
# 5     ZKJ82A1HD     Healthy  R7926
# 6    ZHNCRC04HD  Colorectal  R7926
# 7      ZMC208HD  Colorectal  R7926
# 8     ZLABV33HD  Colorectal  R7926
# 9   ZMLAAAB10HD  Colorectal  R7926
# 10    ZYCAB80HD  Colorectal  R7926
# 11    ZKI83A1HD     Healthy  R7926
# 12    ZKI56A1HD     Healthy  R7926
# 13    ZKI77A1HD     Healthy  R7926
# 14    ZKI98A1HD     Healthy  R7926
# 15    ZKJ07A1HD     Healthy  R7926
# 16    ZKJ44A1HD     Healthy  R7926
# 17     ZLBG97HD     Gastric  R7926
# 18    ZLBG100HD     Gastric  R7926
# 19    ZLHAC03HD     Gastric  R7926
# 20   ZHNGK181HD     Gastric  R7926
# 21   ZHNGK183HD     Gastric  R7926
# 22   ZHNGK185HD     Gastric  R7926
# 23    ZKJ24A1HD     Healthy  R7780
# 24    ZKJ36A1HD     Healthy  R7780
# ...
